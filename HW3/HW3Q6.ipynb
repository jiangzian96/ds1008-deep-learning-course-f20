# %% [markdown]
# ### Energy-based models assignment; implementation problem
#
# This is a (hopefully shorter, compared to hw2) implementation problem of the third assignment. We will investigate convolutional auto-encoders and denoising convolutional auto-encoders.

# %% [markdown]
# ### Prereqs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Question 1 (of this notebook):**
#
# Estimated time: 10 min.
#
# We first load the data.
#
# TODO:
# - Print out a few shapes. See comments in the below cell. Can be done in three lines of code, but you're welcome to provide a more complicated solution.

# %%
import datetime
import logging
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import sys

import torch
import torch.nn as nn
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.utils import data
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms


def load_fashion_mnist(batch_size=64):
    # One convention (of the many) is to use a real number between -1 and 1
    # (inclusive) to represent each pixel; instead of an integer from 0 to 255.
    transform = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize([0.5], [0.5])])

    train_dataset = datasets.FashionMNIST(root='./data', train=True,
                                          download=True, transform=transform)

    # Create validation set from training set, given that torchvision only gives
    # us the train/test split.  
    num_train = len(train_dataset)
    indices = list(range(num_train))
    valid_size = 0.1
    split = int(np.floor(valid_size * num_train))

    random_seed = 123
    np.random.seed(random_seed)  # think: why do we do this?
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = data.SubsetRandomSampler(train_idx)
    valid_sampler = data.SubsetRandomSampler(valid_idx)
    train_loader = data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler)
    valid_loader = data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=valid_sampler)
    test_dataset = datasets.FashionMNIST(root='./data', train=False,
                                         download=True, transform=transform)
    test_loader = data.DataLoader(test_dataset, batch_size=batch_size,
                                  shuffle=False)
    
    # TODO: the images in training, validation, and test sets have shape:
    # [num of examples, image height, image weight];
    # write a few lines of code to print out the three (train/val/test) shapes;
    # for example, the test set image shape should be [10000, 28, 28];
    # try exploring the dataset using test_dataset[7], test_dataset.data, etc.
    print(torch.rand(len(train_loader.dataset)-len(valid_idx), next(iter(train_loader))[0].size(-2), next(iter(train_loader))[0].size(-1)).shape)
    print(torch.rand(len(valid_idx), next(iter(valid_loader))[0].size(-2),next(iter(valid_loader))[0].size(-1)).shape)
    print(test_dataset.data.shape)

    return train_loader, valid_loader, test_loader

def imshow(img):
    # First unnormalize if we want to print out the image. We're using the
    # convention that each image pixel is between -1 and 1. But when python
    # prints out images, the pixel needs to be between 0 and 1.
    img = img / 2 + 0.5
    img_numpy = img.numpy()
    plt.figure(figsize=(12, 12))
    plt.imshow(np.transpose(img_numpy, (1, 2, 0)))

# %%
batch_size = 64
train_loader, valid_loader, test_loader = load_fashion_mnist(batch_size)
# Out:
# torch.Size([54000, 28, 28])
# torch.Size([6000, 28, 28])
# torch.Size([10000, 28, 28])

# %%
# !nvidia-smi  # make sure you're using GPUs when you are about to train the model
# Out:
# Thu Oct 29 06:13:28 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    29W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Taking a look at what the images are like
images = next(iter(test_loader))[0][:64]
imshow(torchvision.utils.make_grid(images, nrow=16))

# %%
images.shape
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# Check out the ten classes on page 3: https://arxiv.org/pdf/1708.07747.pdf
# - 0: t-shirt/top; 1: trouser; 2: pullover; 3: dress; 4: coat; 5: sandals; 6: shirt; 7: sneaker; 8: bag; 9: ankle boots.
#
# <!-- For CIFAR10, check out the ten classes here: https://www.cs.toronto.edu/~kriz/cifar.html
# - Airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck -->
#
# This dataset is much more difficult on the classification task, compared to the digit MNIST which we saw in Lab 2. However, **today we will NOT be doing classification!!! So let's assume that the labels DO NOT EXIST in the iterators (the data loaders)!**

# %% [markdown]
# ### Model

# %% [markdown]
# Next, we will implement two versions of autoencoders: (1) convolutional autoencoder; (2) denoising convolutional autoencoder (but actually we'll be using the same model code, explained later).

# %% [markdown]
# **Question 2: implement a convolutional autoencoder**
#
# Estimated time: 30 min.
#
# TODO
# - In CAE class below, complete the init function and the forward function, such that your implementation satisfies the following requirements.
#   - The output image dimension (from the forward function) is exactly the same as the input image dimension.
#   - There are two Conv2d layer in the encoder, followed by three Conv2d or ConvTranspose2d blocks in the decoder. The out_channel for the second convolutional layer in the encoder should be >= 16 (for example, 16 or 32; feel free to experiment other choices).
#     - Use ReLU or some other similar nonlinearities, followed by pooling, after each convolution layer in the encoder.
#     - Use ReLU or some other similar nonlinearities, after each convolution layer in the decoder (except for the very last convolution layer). Suggestion (but no need to follow this advice): the out_channel size for the decoder convolutional layers should be smaller and smaller (meaning the out_channel for first decoding conv2d layer should be bigger than out_channel for second decoding conv2d layer).
#     - Add batch normalization layers after the nonlinearities, just like what you may have done in the previous homework.
#     - In decoder, if you want to obtain an output feature map with size larger than size of input feature map, consider using ConvTranspose2d, or UpsamplingBilinear2d, after figuring out what they do.
#     - No hard requirement on what padding or stride to use, but make sure they're small, given that our image is only 28*28.
#   - Note that your parameters (e.g., number of filters in the intermediate layers) should not be too big, given that our image is greyscale and has 28*28 pixels only.

# %%
cuda = torch.cuda.is_available()
device = torch.device('cuda' if cuda else 'cpu')

# %%
import torch.nn.functional as F

class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            nn.Conv2d(in_channels=32, out_channels=16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        )
        self.decoder = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            nn.Conv2d(in_channels=32, out_channels=16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(16),
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            nn.Conv2d(in_channels=16, out_channels=1, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(1),
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        )
    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        out = self.encoder(y)
        out = self.decoder(out)
        return out

# %%
model = CAE()
model(images).shape
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# **Question 3: complete the train() and validate() function to be used later**
#
# Estimated time: 10 min.
#
# TODO
# - Complete the train() function.
#   - Hint: recall the five steps we discussed in Lab 2.
#   - Make sure your images are on GPUs (device cuda) before you train. Otherwise, your training may be extremely extremely slow and it may take you 50 times longer than other people.
#
# - Complete the validate() function:
#   - The only thing we need to do is to save the model when we achieve the best validation loss so far. So, check out the pytorch documentation or the third lab, for how to save checkpoints. Make sure to do this step because we need to load the model later.

# %%
torch.rand(images.shape[0]).view(-1, 1, 1, 1).shape
# Out:
# torch.Size([64, 1, 1, 1])

# %%
# This is part of question 4.
def add_noise(images):
    noise = torch.randn(images.size())
    C = torch.rand(noise.size(0))
    noise = noise.view(images.size(0), -1) * C.view(images.size(0), -1)
    noise = noise.to(images.device)
    images_noisy = images + noise.view(-1, 1, 28, 28)
    return torch.clamp(images_noisy, -1.0, 1.0)

imshow(torchvision.utils.make_grid(add_noise(images).cpu().data))

# %%
def train(autoencoder, train_loader, epoch, num_epoch, learning_rate, log_interval, denoising=False):
    # Using sum reduction simply bc otherwise, the scale of the loss is too small;
    # given that we always have 28*28 images, using sum/mean reduction wouldn't
    # make a difference.
    criteria = nn.MSELoss(reduction='sum')
    optimizer = torch.optim.Adam(
        autoencoder.parameters(), lr=learning_rate)

    autoencoder.train()
    for i, data in enumerate(train_loader):
        images, _ = data
        images = images.to(device)
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        out = autoencoder(input_images)
        optimizer.zero_grad()
        loss = criteria(out, images)
        loss.backward()
        optimizer.step()
        if (i + 1) % log_interval == 0:
            print('Epoch [{}/{}] - Iter[{}/{}], MSE loss:{:.6f}'.format(
                epoch + 1, num_epoch, i + 1,
                len(train_loader.dataset) // batch_size, loss.item() / batch_size
            ))


def validate(autoencoder, valid_loader, best_val_loss, denoising=False):
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    for i, data in enumerate(valid_loader):
        images, _ = data
        images = images.to(device)
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        outputs = autoencoder(input_images)
        loss = criteria(outputs, images)
        total_loss += float(loss)
    avg_loss = total_loss / (len(valid_loader) * batch_size)

    print('\nLoss per image on validation set: {:.6f}'.format(avg_loss))

    if avg_loss < best_val_loss:
        if denoising:
            save_path = '/content/drive/My Drive/DS1008/HW3/model_denoising.pth'
        else:
            save_path = '/content/drive/My Drive/DS1008/HW3/model.pth'
        best_val_loss = avg_loss
        checkpoint = { 
            'model': autoencoder.state_dict()
            }
        torch.save(checkpoint, save_path)
        print('Saved best model in the checkpoint directory\n')
    
    return best_val_loss

def evaluate(autoencoder, test_loader, denoising=False):
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    for i, data in enumerate(test_loader):
        images, _ = data
        images = images.to(device)
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        outputs = autoencoder(input_images)
        loss = criteria(outputs, images)
        total_loss += float(loss)
    avg_loss = total_loss / (len(test_loader) * batch_size)

    print('\nMSE loss per image on test set: {:.6f}'.format(avg_loss))

# %% [markdown]
# **Question 4: implement a denoising convolutional autoencoder**
#
# Estimated time: 20 min.
#
# The input to a denoising CAE is a perturbed image, and the output is the original image. Given that we're using the same network, there's nothing we need to change about the CAE class.
#
# TODO
# - However, add an argument called ```denoising``` (defaulted to be ```False```) in the train() to indicate if our input will be the noisy version (in this case ```denoising=True```) or a clean version (in this case ```denoising=False```), and modify the functions appropriately, with the following instructions. Do the same for validate() and evaluate() to decide if we want to validate/evaluate on noisy or clean images.
#
# - Perturbation (i.e., making images noisy)
#   - First make sure that each pixels are represented by a real number from -1 to 1 (instead of integers from 0 to 255). The pixel should be already from -1 to 1, unless you did something you shouldn't have done.
#   - Next, do a perturbation to each image where the noise is sampled according to the standard Gaussian distribution and then multiplied by a number uniformly sampled from 0 to 1.
#     - In other words, each pixel in image i should be perturbed with a noise (1) sampled from a standard Gaussian distribution and then (2) multiplied by $c_i$ for some $c_i \in (0,1)$, and each pixel in image j should be perturbed with a noise (1) sampled from a standard Gaussian distribution and then (2) multiplied by $c_j$ for some $c_j \in (0,1)$. (In fact, the result is that for each image, we're still sampling the noise from a Gaussian distribution; the mean is 0, and the standard deviation is sampled from a uniform distribution. Think: why?)
#     - Make sure that the resulting perturbed/noisy image are still represented by numbers from -1 to 1 (so you may need to do some clipping with min -1 and max 1).
#
# - To add noise to a batch of images, please use a helper function called add_noise(), outside the train(), validate(), evaluate() functions.

# %% [markdown]
# **Question 5: Training**
#
# Estimated debugging time: 30 min, or longer if you have more severe bugs.
#
# TODO
#
# - Now, train your CAE model (where your input is the original images), and train your denoising CAE model (where your input is the noisy images). You can set a patience counter on your own (similar to homework 2), meaning if validation loss doesn't decrease for, say, 10 epochs (just an example), then you can stop training. Each training procedure may take half an hour or an hour. It may take many many more hours if you didn't move the model or the data onto GPUs. Moreover, to make sure your training is not lost in case colab disconnects, it's important to save checkpoints! Make sure you wrote the checkpoint saving code in the validate function.
# - Report the best validation loss. No need to plot the curve, but you can plot it nevertheless to have a better understanding on your training process.
#
# Estimated training time in total: 2 hours (depending on your model)?
# - Please do not spend the 2 hours staring at your log.
# - You don't need to get the "best" model. You only need Question 6, Question 7, and Question 8 to work. Q6 works if your reconstructed images aren't bad (okay to be blurry); Q7 works if your plots looks similar to the presented; Q8 works if ...please read Q8.

# %%
batch_size = 64
best_val_loss = float('inf')
num_epoch = 100
learning_rate = 1e-3
log_interval = 100
max_patience = 5
patience_counter = 0

denoising = False
keep_training_from_ckpt = True

if denoising:
    load_path = '/content/drive/My Drive/DS1008/HW3/model_denoising.pth'
else:
    load_path = '/content/drive/My Drive/DS1008/HW3/model.pth'

conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

if keep_training_from_ckpt:
    conv_autoencoder.load_state_dict(torch.load(load_path)["model"])
for epoch in range(num_epoch):
    start_time = datetime.datetime.now()
    train(conv_autoencoder, train_loader, epoch, num_epoch, learning_rate, log_interval, denoising)
    end_time = datetime.datetime.now()
    print(f'Trained this epoch using {(end_time - start_time).seconds} seconds')
    # validate and save model if it's the best model so far
    prev = best_val_loss
    best_val_loss = validate(conv_autoencoder, valid_loader, prev,
                             denoising)
    if best_val_loss < prev:
      patience_counter = 0
      prev = best_val_loss
    else:
      patience_counter += 1
      if patience_counter > max_patience:
        break
print('Training done; best validation loss {:.4f}'.format(best_val_loss))
# Out:
# Epoch [1/100] - Iter[100/937], MSE loss:24.351768
# Epoch [1/100] - Iter[200/937], MSE loss:22.618443
# Epoch [1/100] - Iter[300/937], MSE loss:24.376925
# Epoch [1/100] - Iter[400/937], MSE loss:19.657848
# Epoch [1/100] - Iter[500/937], MSE loss:24.856716
# Epoch [1/100] - Iter[600/937], MSE loss:20.689682
# Epoch [1/100] - Iter[700/937], MSE loss:19.669462
# Epoch [1/100] - Iter[800/937], MSE loss:18.443439
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 18.664175
# Saved best model in the checkpoint directory
#
# Epoch [2/100] - Iter[100/937], MSE loss:17.839148
# Epoch [2/100] - Iter[200/937], MSE loss:20.034145
# Epoch [2/100] - Iter[300/937], MSE loss:22.519966
# Epoch [2/100] - Iter[400/937], MSE loss:19.296619
# Epoch [2/100] - Iter[500/937], MSE loss:17.819639
# Epoch [2/100] - Iter[600/937], MSE loss:20.972223
# Epoch [2/100] - Iter[700/937], MSE loss:20.131264
# Epoch [2/100] - Iter[800/937], MSE loss:15.104397
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 19.815617
# Epoch [3/100] - Iter[100/937], MSE loss:19.044714
# Epoch [3/100] - Iter[200/937], MSE loss:17.854492
# Epoch [3/100] - Iter[300/937], MSE loss:20.180473
# Epoch [3/100] - Iter[400/937], MSE loss:17.848660
# Epoch [3/100] - Iter[500/937], MSE loss:16.691261
# Epoch [3/100] - Iter[600/937], MSE loss:18.084993
# Epoch [3/100] - Iter[700/937], MSE loss:18.822929
# Epoch [3/100] - Iter[800/937], MSE loss:24.172100
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 18.038105
# Saved best model in the checkpoint directory
#
# Epoch [4/100] - Iter[100/937], MSE loss:23.372402
# Epoch [4/100] - Iter[200/937], MSE loss:17.216122
# Epoch [4/100] - Iter[300/937], MSE loss:23.824924
# Epoch [4/100] - Iter[400/937], MSE loss:18.486685
# Epoch [4/100] - Iter[500/937], MSE loss:19.473097
# Epoch [4/100] - Iter[600/937], MSE loss:20.088509
# Epoch [4/100] - Iter[700/937], MSE loss:15.958918
# Epoch [4/100] - Iter[800/937], MSE loss:25.701069
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.856481
# Saved best model in the checkpoint directory
#
# Epoch [5/100] - Iter[100/937], MSE loss:20.249582
# Epoch [5/100] - Iter[200/937], MSE loss:17.213224
# Epoch [5/100] - Iter[300/937], MSE loss:17.342056
# Epoch [5/100] - Iter[400/937], MSE loss:21.726130
# Epoch [5/100] - Iter[500/937], MSE loss:22.678907
# Epoch [5/100] - Iter[600/937], MSE loss:16.755341
# Epoch [5/100] - Iter[700/937], MSE loss:15.622747
# Epoch [5/100] - Iter[800/937], MSE loss:17.253536
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.616920
# Saved best model in the checkpoint directory
#
# Epoch [6/100] - Iter[100/937], MSE loss:17.109091
# Epoch [6/100] - Iter[200/937], MSE loss:14.935665
# Epoch [6/100] - Iter[300/937], MSE loss:18.863350
# Epoch [6/100] - Iter[400/937], MSE loss:21.265121
# Epoch [6/100] - Iter[500/937], MSE loss:17.842476
# Epoch [6/100] - Iter[600/937], MSE loss:18.957691
# Epoch [6/100] - Iter[700/937], MSE loss:19.946857
# Epoch [6/100] - Iter[800/937], MSE loss:16.398676
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 18.068131
# Epoch [7/100] - Iter[100/937], MSE loss:17.378021
# Epoch [7/100] - Iter[200/937], MSE loss:16.935574
# Epoch [7/100] - Iter[300/937], MSE loss:18.214087
# Epoch [7/100] - Iter[400/937], MSE loss:17.424891
# Epoch [7/100] - Iter[500/937], MSE loss:24.670959
# Epoch [7/100] - Iter[600/937], MSE loss:17.251640
# Epoch [7/100] - Iter[700/937], MSE loss:19.561264
# Epoch [7/100] - Iter[800/937], MSE loss:23.416607
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.255956
# Saved best model in the checkpoint directory
#
# Epoch [8/100] - Iter[100/937], MSE loss:17.095982
# Epoch [8/100] - Iter[200/937], MSE loss:14.916816
# Epoch [8/100] - Iter[300/937], MSE loss:16.969372
# Epoch [8/100] - Iter[400/937], MSE loss:14.706837
# Epoch [8/100] - Iter[500/937], MSE loss:19.186316
# Epoch [8/100] - Iter[600/937], MSE loss:17.438816
# Epoch [8/100] - Iter[700/937], MSE loss:17.181633
# Epoch [8/100] - Iter[800/937], MSE loss:18.408022
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.016016
# Saved best model in the checkpoint directory
#
# Epoch [9/100] - Iter[100/937], MSE loss:20.946318
# Epoch [9/100] - Iter[200/937], MSE loss:17.749937
# Epoch [9/100] - Iter[300/937], MSE loss:19.448166
# Epoch [9/100] - Iter[400/937], MSE loss:20.616772
# Epoch [9/100] - Iter[500/937], MSE loss:18.194296
# Epoch [9/100] - Iter[600/937], MSE loss:16.349726
# Epoch [9/100] - Iter[700/937], MSE loss:18.333218
# Epoch [9/100] - Iter[800/937], MSE loss:23.160126
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.233029
# Epoch [10/100] - Iter[100/937], MSE loss:16.826809
# Epoch [10/100] - Iter[200/937], MSE loss:16.422501
# Epoch [10/100] - Iter[300/937], MSE loss:17.151552
# Epoch [10/100] - Iter[400/937], MSE loss:16.719532
# Epoch [10/100] - Iter[500/937], MSE loss:19.701729
# Epoch [10/100] - Iter[600/937], MSE loss:16.210842
# Epoch [10/100] - Iter[700/937], MSE loss:17.214104
# Epoch [10/100] - Iter[800/937], MSE loss:17.835920
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.401107
# Epoch [11/100] - Iter[100/937], MSE loss:28.369091
# Epoch [11/100] - Iter[200/937], MSE loss:18.409559
# Epoch [11/100] - Iter[300/937], MSE loss:14.325871
# Epoch [11/100] - Iter[400/937], MSE loss:16.729877
# Epoch [11/100] - Iter[500/937], MSE loss:15.787104
# Epoch [11/100] - Iter[600/937], MSE loss:18.813625
# Epoch [11/100] - Iter[700/937], MSE loss:16.780113
# Epoch [11/100] - Iter[800/937], MSE loss:14.481842
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.325424
# Epoch [12/100] - Iter[100/937], MSE loss:15.858199
# Epoch [12/100] - Iter[200/937], MSE loss:17.205263
# Epoch [12/100] - Iter[300/937], MSE loss:16.796177
# Epoch [12/100] - Iter[400/937], MSE loss:19.550043
# Epoch [12/100] - Iter[500/937], MSE loss:16.749161
# Epoch [12/100] - Iter[600/937], MSE loss:14.012104
# Epoch [12/100] - Iter[700/937], MSE loss:16.313389
# Epoch [12/100] - Iter[800/937], MSE loss:20.639311
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.133556
# Epoch [13/100] - Iter[100/937], MSE loss:18.752069
# Epoch [13/100] - Iter[200/937], MSE loss:16.640184
# Epoch [13/100] - Iter[300/937], MSE loss:19.061146
# Epoch [13/100] - Iter[400/937], MSE loss:17.603073
# Epoch [13/100] - Iter[500/937], MSE loss:18.644079
# Epoch [13/100] - Iter[600/937], MSE loss:18.297123
# Epoch [13/100] - Iter[700/937], MSE loss:17.972622
# Epoch [13/100] - Iter[800/937], MSE loss:19.446177
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.956563
# Epoch [14/100] - Iter[100/937], MSE loss:15.659775
# Epoch [14/100] - Iter[200/937], MSE loss:18.224739
# Epoch [14/100] - Iter[300/937], MSE loss:21.189228
# Epoch [14/100] - Iter[400/937], MSE loss:16.996441
# Epoch [14/100] - Iter[500/937], MSE loss:16.997789
# Epoch [14/100] - Iter[600/937], MSE loss:17.022671
# Epoch [14/100] - Iter[700/937], MSE loss:13.674604
# Epoch [14/100] - Iter[800/937], MSE loss:15.722746
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 17.085090
# Training done; best validation loss 17.0160

# %%
batch_size = 64
best_val_loss = float('inf')
num_epoch = 100
learning_rate = 1e-3
log_interval = 100
max_patience = 5
patience_counter = 0

denoising = True
keep_training_from_ckpt = False

if denoising:
    load_path = '/content/drive/My Drive/DS1008/HW3/model_denoising.pth'
else:
    load_path = '/content/drive/My Drive/DS1008/HW3/model.pth'

conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

if keep_training_from_ckpt:
    conv_autoencoder.load_state_dict(torch.load(load_path)["model"])
for epoch in range(num_epoch):
    start_time = datetime.datetime.now()
    train(conv_autoencoder, train_loader, epoch, num_epoch, learning_rate, log_interval, denoising)
    end_time = datetime.datetime.now()
    print(f'Trained this epoch using {(end_time - start_time).seconds} seconds')
    # validate and save model if it's the best model so far
    prev = best_val_loss
    best_val_loss = validate(conv_autoencoder, valid_loader, prev,
                             denoising)
    if best_val_loss < prev:
      patience_counter = 0
      prev = best_val_loss
    else:
      patience_counter += 1
      if patience_counter > max_patience:
        break
print('Training done; best validation loss {:.4f}'.format(best_val_loss))
# Out:
# Epoch [1/100] - Iter[100/937], MSE loss:381.675232
# Epoch [1/100] - Iter[200/937], MSE loss:280.291626
# Epoch [1/100] - Iter[300/937], MSE loss:158.364502
# Epoch [1/100] - Iter[400/937], MSE loss:121.438057
# Epoch [1/100] - Iter[500/937], MSE loss:82.373314
# Epoch [1/100] - Iter[600/937], MSE loss:62.909599
# Epoch [1/100] - Iter[700/937], MSE loss:58.193817
# Epoch [1/100] - Iter[800/937], MSE loss:52.164070
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 45.842460
# Saved best model in the checkpoint directory
#
# Epoch [2/100] - Iter[100/937], MSE loss:39.411205
# Epoch [2/100] - Iter[200/937], MSE loss:37.950233
# Epoch [2/100] - Iter[300/937], MSE loss:37.496506
# Epoch [2/100] - Iter[400/937], MSE loss:37.504044
# Epoch [2/100] - Iter[500/937], MSE loss:39.942295
# Epoch [2/100] - Iter[600/937], MSE loss:40.364952
# Epoch [2/100] - Iter[700/937], MSE loss:33.277554
# Epoch [2/100] - Iter[800/937], MSE loss:34.510567
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 38.069349
# Saved best model in the checkpoint directory
#
# Epoch [3/100] - Iter[100/937], MSE loss:35.261902
# Epoch [3/100] - Iter[200/937], MSE loss:40.956783
# Epoch [3/100] - Iter[300/937], MSE loss:34.112488
# Epoch [3/100] - Iter[400/937], MSE loss:36.067432
# Epoch [3/100] - Iter[500/937], MSE loss:38.308468
# Epoch [3/100] - Iter[600/937], MSE loss:34.014618
# Epoch [3/100] - Iter[700/937], MSE loss:34.973419
# Epoch [3/100] - Iter[800/937], MSE loss:33.705986
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 34.672115
# Saved best model in the checkpoint directory
#
# Epoch [4/100] - Iter[100/937], MSE loss:35.928562
# Epoch [4/100] - Iter[200/937], MSE loss:35.177635
# Epoch [4/100] - Iter[300/937], MSE loss:35.839249
# Epoch [4/100] - Iter[400/937], MSE loss:36.729813
# Epoch [4/100] - Iter[500/937], MSE loss:40.106949
# Epoch [4/100] - Iter[600/937], MSE loss:36.528416
# Epoch [4/100] - Iter[700/937], MSE loss:34.986992
# Epoch [4/100] - Iter[800/937], MSE loss:38.213020
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 34.152692
# Saved best model in the checkpoint directory
#
# Epoch [5/100] - Iter[100/937], MSE loss:32.615295
# Epoch [5/100] - Iter[200/937], MSE loss:32.368488
# Epoch [5/100] - Iter[300/937], MSE loss:33.585670
# Epoch [5/100] - Iter[400/937], MSE loss:36.483765
# Epoch [5/100] - Iter[500/937], MSE loss:39.621292
# Epoch [5/100] - Iter[600/937], MSE loss:34.559250
# Epoch [5/100] - Iter[700/937], MSE loss:34.989178
# Epoch [5/100] - Iter[800/937], MSE loss:30.986822
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 33.763638
# Saved best model in the checkpoint directory
#
# Epoch [6/100] - Iter[100/937], MSE loss:36.120178
# Epoch [6/100] - Iter[200/937], MSE loss:37.279812
# Epoch [6/100] - Iter[300/937], MSE loss:31.018517
# Epoch [6/100] - Iter[400/937], MSE loss:40.231014
# Epoch [6/100] - Iter[500/937], MSE loss:32.962433
# Epoch [6/100] - Iter[600/937], MSE loss:40.255810
# Epoch [6/100] - Iter[700/937], MSE loss:35.184761
# Epoch [6/100] - Iter[800/937], MSE loss:35.267971
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 33.913367
# Epoch [7/100] - Iter[100/937], MSE loss:34.863136
# Epoch [7/100] - Iter[200/937], MSE loss:38.463593
# Epoch [7/100] - Iter[300/937], MSE loss:35.499634
# Epoch [7/100] - Iter[400/937], MSE loss:35.063728
# Epoch [7/100] - Iter[500/937], MSE loss:36.012516
# Epoch [7/100] - Iter[600/937], MSE loss:35.870995
# Epoch [7/100] - Iter[700/937], MSE loss:30.706356
# Epoch [7/100] - Iter[800/937], MSE loss:34.930374
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 33.784852
# Epoch [8/100] - Iter[100/937], MSE loss:31.197289
# Epoch [8/100] - Iter[200/937], MSE loss:36.211189
# Epoch [8/100] - Iter[300/937], MSE loss:38.601273
# Epoch [8/100] - Iter[400/937], MSE loss:34.607471
# Epoch [8/100] - Iter[500/937], MSE loss:36.576626
# Epoch [8/100] - Iter[600/937], MSE loss:29.928024
# Epoch [8/100] - Iter[700/937], MSE loss:33.473934
# Epoch [8/100] - Iter[800/937], MSE loss:40.322792
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.945854
# Saved best model in the checkpoint directory
#
# Epoch [9/100] - Iter[100/937], MSE loss:31.101891
# Epoch [9/100] - Iter[200/937], MSE loss:32.726299
# Epoch [9/100] - Iter[300/937], MSE loss:32.188744
# Epoch [9/100] - Iter[400/937], MSE loss:33.524048
# Epoch [9/100] - Iter[500/937], MSE loss:37.051224
# Epoch [9/100] - Iter[600/937], MSE loss:36.173569
# Epoch [9/100] - Iter[700/937], MSE loss:41.976006
# Epoch [9/100] - Iter[800/937], MSE loss:45.987595
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 33.267867
# Epoch [10/100] - Iter[100/937], MSE loss:33.396667
# Epoch [10/100] - Iter[200/937], MSE loss:34.777554
# Epoch [10/100] - Iter[300/937], MSE loss:41.793056
# Epoch [10/100] - Iter[400/937], MSE loss:37.630917
# Epoch [10/100] - Iter[500/937], MSE loss:33.331989
# Epoch [10/100] - Iter[600/937], MSE loss:35.621784
# Epoch [10/100] - Iter[700/937], MSE loss:34.485214
# Epoch [10/100] - Iter[800/937], MSE loss:30.771795
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.795261
# Saved best model in the checkpoint directory
#
# Epoch [11/100] - Iter[100/937], MSE loss:37.861931
# Epoch [11/100] - Iter[200/937], MSE loss:29.178284
# Epoch [11/100] - Iter[300/937], MSE loss:33.964897
# Epoch [11/100] - Iter[400/937], MSE loss:34.636787
# Epoch [11/100] - Iter[500/937], MSE loss:34.041111
# Epoch [11/100] - Iter[600/937], MSE loss:31.360939
# Epoch [11/100] - Iter[700/937], MSE loss:34.090363
# Epoch [11/100] - Iter[800/937], MSE loss:33.749741
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 33.105604
# Epoch [12/100] - Iter[100/937], MSE loss:39.075321
# Epoch [12/100] - Iter[200/937], MSE loss:35.320393
# Epoch [12/100] - Iter[300/937], MSE loss:29.546078
# Epoch [12/100] - Iter[400/937], MSE loss:33.478554
# Epoch [12/100] - Iter[500/937], MSE loss:32.607315
# Epoch [12/100] - Iter[600/937], MSE loss:34.975849
# Epoch [12/100] - Iter[700/937], MSE loss:33.411316
# Epoch [12/100] - Iter[800/937], MSE loss:33.706650
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.850963
# Epoch [13/100] - Iter[100/937], MSE loss:31.635456
# Epoch [13/100] - Iter[200/937], MSE loss:30.346188
# Epoch [13/100] - Iter[300/937], MSE loss:33.010826
# Epoch [13/100] - Iter[400/937], MSE loss:32.405037
# Epoch [13/100] - Iter[500/937], MSE loss:35.054459
# Epoch [13/100] - Iter[600/937], MSE loss:31.356728
# Epoch [13/100] - Iter[700/937], MSE loss:34.580395
# Epoch [13/100] - Iter[800/937], MSE loss:34.799389
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.705970
# Saved best model in the checkpoint directory
#
# Epoch [14/100] - Iter[100/937], MSE loss:30.818363
# Epoch [14/100] - Iter[200/937], MSE loss:36.766571
# Epoch [14/100] - Iter[300/937], MSE loss:38.297077
# Epoch [14/100] - Iter[400/937], MSE loss:35.964935
# Epoch [14/100] - Iter[500/937], MSE loss:33.769409
# Epoch [14/100] - Iter[600/937], MSE loss:29.003624
# Epoch [14/100] - Iter[700/937], MSE loss:34.025421
# Epoch [14/100] - Iter[800/937], MSE loss:38.093483
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.624208
# Saved best model in the checkpoint directory
#
# Epoch [15/100] - Iter[100/937], MSE loss:34.767876
# Epoch [15/100] - Iter[200/937], MSE loss:34.242714
# Epoch [15/100] - Iter[300/937], MSE loss:32.291176
# Epoch [15/100] - Iter[400/937], MSE loss:36.393574
# Epoch [15/100] - Iter[500/937], MSE loss:33.303650
# Epoch [15/100] - Iter[600/937], MSE loss:31.862226
# Epoch [15/100] - Iter[700/937], MSE loss:29.166147
# Epoch [15/100] - Iter[800/937], MSE loss:28.924629
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.799308
# Epoch [16/100] - Iter[100/937], MSE loss:31.325447
# Epoch [16/100] - Iter[200/937], MSE loss:37.502052
# Epoch [16/100] - Iter[300/937], MSE loss:33.772385
# Epoch [16/100] - Iter[400/937], MSE loss:36.931610
# Epoch [16/100] - Iter[500/937], MSE loss:36.033192
# Epoch [16/100] - Iter[600/937], MSE loss:33.349373
# Epoch [16/100] - Iter[700/937], MSE loss:31.475636
# Epoch [16/100] - Iter[800/937], MSE loss:35.562378
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.706486
# Epoch [17/100] - Iter[100/937], MSE loss:34.649204
# Epoch [17/100] - Iter[200/937], MSE loss:39.086525
# Epoch [17/100] - Iter[300/937], MSE loss:37.574196
# Epoch [17/100] - Iter[400/937], MSE loss:33.057579
# Epoch [17/100] - Iter[500/937], MSE loss:33.271442
# Epoch [17/100] - Iter[600/937], MSE loss:34.620762
# Epoch [17/100] - Iter[700/937], MSE loss:34.629719
# Epoch [17/100] - Iter[800/937], MSE loss:31.353897
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.410097
# Saved best model in the checkpoint directory
#
# Epoch [18/100] - Iter[100/937], MSE loss:30.877346
# Epoch [18/100] - Iter[200/937], MSE loss:34.583744
# Epoch [18/100] - Iter[300/937], MSE loss:38.213287
# Epoch [18/100] - Iter[400/937], MSE loss:33.788738
# Epoch [18/100] - Iter[500/937], MSE loss:36.303238
# Epoch [18/100] - Iter[600/937], MSE loss:35.470684
# Epoch [18/100] - Iter[700/937], MSE loss:34.428299
# Epoch [18/100] - Iter[800/937], MSE loss:31.230688
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.211093
# Saved best model in the checkpoint directory
#
# Epoch [19/100] - Iter[100/937], MSE loss:33.915176
# Epoch [19/100] - Iter[200/937], MSE loss:33.437340
# Epoch [19/100] - Iter[300/937], MSE loss:36.759933
# Epoch [19/100] - Iter[400/937], MSE loss:33.434380
# Epoch [19/100] - Iter[500/937], MSE loss:36.423958
# Epoch [19/100] - Iter[600/937], MSE loss:32.887211
# Epoch [19/100] - Iter[700/937], MSE loss:28.939331
# Epoch [19/100] - Iter[800/937], MSE loss:35.511436
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.519436
# Epoch [20/100] - Iter[100/937], MSE loss:33.292267
# Epoch [20/100] - Iter[200/937], MSE loss:32.634235
# Epoch [20/100] - Iter[300/937], MSE loss:32.944168
# Epoch [20/100] - Iter[400/937], MSE loss:30.951605
# Epoch [20/100] - Iter[500/937], MSE loss:33.675781
# Epoch [20/100] - Iter[600/937], MSE loss:32.603558
# Epoch [20/100] - Iter[700/937], MSE loss:28.945700
# Epoch [20/100] - Iter[800/937], MSE loss:27.121632
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.551841
# Epoch [21/100] - Iter[100/937], MSE loss:32.217567
# Epoch [21/100] - Iter[200/937], MSE loss:33.826729
# Epoch [21/100] - Iter[300/937], MSE loss:30.429848
# Epoch [21/100] - Iter[400/937], MSE loss:33.195854
# Epoch [21/100] - Iter[500/937], MSE loss:33.787956
# Epoch [21/100] - Iter[600/937], MSE loss:30.360004
# Epoch [21/100] - Iter[700/937], MSE loss:32.926521
# Epoch [21/100] - Iter[800/937], MSE loss:28.394571
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.520957
# Epoch [22/100] - Iter[100/937], MSE loss:35.458553
# Epoch [22/100] - Iter[200/937], MSE loss:29.213692
# Epoch [22/100] - Iter[300/937], MSE loss:32.600220
# Epoch [22/100] - Iter[400/937], MSE loss:33.104324
# Epoch [22/100] - Iter[500/937], MSE loss:30.828884
# Epoch [22/100] - Iter[600/937], MSE loss:33.627789
# Epoch [22/100] - Iter[700/937], MSE loss:30.799603
# Epoch [22/100] - Iter[800/937], MSE loss:32.089622
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.210538
# Saved best model in the checkpoint directory
#
# Epoch [23/100] - Iter[100/937], MSE loss:32.159058
# Epoch [23/100] - Iter[200/937], MSE loss:29.715870
# Epoch [23/100] - Iter[300/937], MSE loss:33.652374
# Epoch [23/100] - Iter[400/937], MSE loss:33.207806
# Epoch [23/100] - Iter[500/937], MSE loss:42.406429
# Epoch [23/100] - Iter[600/937], MSE loss:36.537704
# Epoch [23/100] - Iter[700/937], MSE loss:32.482964
# Epoch [23/100] - Iter[800/937], MSE loss:30.835167
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 31.971168
# Saved best model in the checkpoint directory
#
# Epoch [24/100] - Iter[100/937], MSE loss:32.421516
# Epoch [24/100] - Iter[200/937], MSE loss:36.598396
# Epoch [24/100] - Iter[300/937], MSE loss:29.232822
# Epoch [24/100] - Iter[400/937], MSE loss:36.730419
# Epoch [24/100] - Iter[500/937], MSE loss:34.872246
# Epoch [24/100] - Iter[600/937], MSE loss:32.186489
# Epoch [24/100] - Iter[700/937], MSE loss:30.619888
# Epoch [24/100] - Iter[800/937], MSE loss:30.506901
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.131490
# Epoch [25/100] - Iter[100/937], MSE loss:40.869572
# Epoch [25/100] - Iter[200/937], MSE loss:28.494076
# Epoch [25/100] - Iter[300/937], MSE loss:28.121246
# Epoch [25/100] - Iter[400/937], MSE loss:29.583111
# Epoch [25/100] - Iter[500/937], MSE loss:29.667360
# Epoch [25/100] - Iter[600/937], MSE loss:31.839516
# Epoch [25/100] - Iter[700/937], MSE loss:31.019705
# Epoch [25/100] - Iter[800/937], MSE loss:31.562725
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.276813
# Epoch [26/100] - Iter[100/937], MSE loss:33.906982
# Epoch [26/100] - Iter[200/937], MSE loss:31.741617
# Epoch [26/100] - Iter[300/937], MSE loss:38.268486
# Epoch [26/100] - Iter[400/937], MSE loss:32.728230
# Epoch [26/100] - Iter[500/937], MSE loss:34.662697
# Epoch [26/100] - Iter[600/937], MSE loss:33.798882
# Epoch [26/100] - Iter[700/937], MSE loss:35.888409
# Epoch [26/100] - Iter[800/937], MSE loss:33.927238
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.233227
# Epoch [27/100] - Iter[100/937], MSE loss:32.032223
# Epoch [27/100] - Iter[200/937], MSE loss:31.776337
# Epoch [27/100] - Iter[300/937], MSE loss:37.374546
# Epoch [27/100] - Iter[400/937], MSE loss:34.284904
# Epoch [27/100] - Iter[500/937], MSE loss:33.805462
# Epoch [27/100] - Iter[600/937], MSE loss:29.498547
# Epoch [27/100] - Iter[700/937], MSE loss:29.062784
# Epoch [27/100] - Iter[800/937], MSE loss:31.321424
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.273033
# Epoch [28/100] - Iter[100/937], MSE loss:31.072186
# Epoch [28/100] - Iter[200/937], MSE loss:31.523609
# Epoch [28/100] - Iter[300/937], MSE loss:30.399727
# Epoch [28/100] - Iter[400/937], MSE loss:32.665363
# Epoch [28/100] - Iter[500/937], MSE loss:33.235588
# Epoch [28/100] - Iter[600/937], MSE loss:40.671078
# Epoch [28/100] - Iter[700/937], MSE loss:26.905830
# Epoch [28/100] - Iter[800/937], MSE loss:34.729073
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.134060
# Epoch [29/100] - Iter[100/937], MSE loss:30.779558
# Epoch [29/100] - Iter[200/937], MSE loss:31.610619
# Epoch [29/100] - Iter[300/937], MSE loss:29.048872
# Epoch [29/100] - Iter[400/937], MSE loss:32.659836
# Epoch [29/100] - Iter[500/937], MSE loss:39.484325
# Epoch [29/100] - Iter[600/937], MSE loss:30.151028
# Epoch [29/100] - Iter[700/937], MSE loss:30.338514
# Epoch [29/100] - Iter[800/937], MSE loss:32.097832
# Trained this epoch using 12 seconds
#
# Loss per image on validation set: 32.002401
# Training done; best validation loss 31.9712

# %% [markdown]
# **Question 6: evaluate on test sets**
#
# Estimated time: 10 min.
#
# Only run the below cell when you're done with training, and you're evaluating on test sets.
#
# TODO:
# - Print out the reconstruction loss on test set for both the CAE and denoising CAE models.
# - Print out a few reconstructed images (for both models). Here, the input to CAE should be clean images; the input to denoising CAE should be noisy images. It's perfectly fine if your reconstructed images are blurry. If your reconstructed image is extremely bad (for example, if you absolutely can't tell what object it is anymore), then you probably made a mistake in the previous steps. You might have chosen an overly small out_channel, for example. Or, learning might be inadequate. Or, you made a mistake in model saving / model loading.

# %%
conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

# %%
# Only run at evaluation time!

def print_loss_and_reconstructed_images(denoising):
    if denoising:
        conv_autoencoder.load_state_dict(torch.load('/content/drive/My Drive/DS1008/HW3/model_denoising.pth')["model"])
    else:
        conv_autoencoder.load_state_dict(torch.load('/content/drive/My Drive/DS1008/HW3/model.pth')["model"])
    if cuda:
        conv_autoencoder.cuda()
    # TODO: evaluate on test set and print out reconstruction loss
    evaluate(conv_autoencoder, test_loader, denoising)

    #conv_autoencoder.cpu()
    # TODO: print out a few (perhaps 16 or 32) reconstructed images for both models
    # no need to follow the below code
    #conv_autoencoder.cpu()
    dataiter = iter(test_loader)
    images, _ = next(dataiter)
    images = images[:32]
    images = images.to(device)
    if denoising:
        images_noisy = add_noise(images)
    else:
        images_noisy = images
    outputs = conv_autoencoder(images_noisy)

    plt.figure()
    imshow(torchvision.utils.make_grid(images_noisy.cpu().data))
    plt.figure()
    imshow(torchvision.utils.make_grid(outputs.cpu().data))

# %%
print_loss_and_reconstructed_images(False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# MSE loss per image on test set: 16.986584

# %%
print_loss_and_reconstructed_images(True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# MSE loss per image on test set: 32.143716

# %% [markdown]
# ### Plotting loss vs. noise length

# %% [markdown]
# **Question 7: plot loss vs. noise length**
#
# Estimated time: 30 min.
#
# TODO:
# For both CAE and denoising CAE models you trained, plot loss vs. noise length, for five different images in five separate plots.
# - Terminology
#   - The noise length is the L2 norm of the noise you added to the image. So, it will be the norm of image_noisy minus image.
#   - The loss refers to the reconstruction loss.
#
# - For each image...
#   - **In this part, the input to both CAE and denoising CAE should be noisy images.** But how much noise?
#   - For each image, at least add 100 different noises with different length (so we're doing at least 100 "trials"). Perhaps you can use different standard deviations in the Gaussian distribution (when you add the noise into the images). For example, you can refer to the provided add_noise_coeff function with coeff as an input argument. You don't need to use this function.
#   - Compute the reconstruction loss for each noise you added.
#   - Now you would have the following list [(noise length #1, loss #1), (noise length #2, loss #2), ..., (noise length #n, loss #n)] (where n is at least 100) for CAE. You should have a similar list for denoising CAE. Now plot the loss (vertical axis) and length (horizontal axis), of two models, in the same plot. But note that the plot only corresponds to one original clean image.
#
# - Do the above for 3 different images.
#
# - Feel free to use get_length_and_loss as a template. However, absolutely no need to follow the logic of get_length_and_loss.
#
# - For each image, you should see a plot similar to the below trend. Think: why? No need to explain.

# %%
def add_noise_coeff(images, coeff):
    noise = torch.mul(
        torch.randn(images.shape),
        torch.tensor([coeff]).view(-1, 1, 1, 1)).to(device)
    images_noisy = images + noise
    images_noisy = torch.clamp(images_noisy, -1.0, 1.0)
    length = torch.norm(noise.view(images.size(0), -1), dim=1)
    return images_noisy, length.detach().cpu().numpy()

# %%
five_images = next(iter(test_loader))[0][0:5].to(device)

# %%
add_noise_coeff(five_images, 0.1)[1]
# Out:
# array([2.7607472, 2.7600646, 2.7933378, 2.7075756, 2.8588526],
#       dtype=float32)

# %%
# Plot loss vs. length

denoising = False

loss_cae = np.array([])
length_cae = np.array([])
loss_dcae = np.array([])
length_dcae = np.array([])

def get_length_and_loss(five_images, denoising):
    loss_ae = []
    length_ae = []
    autoencoder = CAE()

    if denoising:
        autoencoder.load_state_dict(torch.load('/content/drive/My Drive/DS1008/HW3/model_denoising.pth')["model"])
    else:
        autoencoder.load_state_dict(torch.load('/content/drive/My Drive/DS1008/HW3/model.pth')["model"])
    if cuda:
        autoencoder.cuda()

    total_loss = 0
    criteria = nn.MSELoss(reduction='none')
    autoencoder.eval()
    
    coefficient = 0.0
    while coefficient < 1.0:
        coefficient += 0.01
        noisy_five_images, length = add_noise_coeff(five_images, coefficient)
        outs = autoencoder(noisy_five_images)
        reconstruction_loss = criteria(outs.view(5, -1), five_images.view(5, -1)).sum(1).detach().cpu().numpy()
        loss_ae = np.append(loss_ae, reconstruction_loss, axis=0)
        length_ae = np.append(length_ae, length)

    return loss_ae.reshape(-1, 5), length_ae.reshape(-1, 5)

# %%
noisy_five_images, length = add_noise_coeff(five_images, 0.5)
imshow(torchvision.utils.make_grid(noisy_five_images.cpu().data))

# %%
import matplotlib.pyplot as plt

for i in range(5):
  loss_cae, length_cae = get_length_and_loss(five_images, False)
  loss_dcae, length_dcae = get_length_and_loss(five_images, True)
  loss_cae = [float(x) for x in loss_cae[:, i]]
  length_cae = [float(x) for x in length_cae[:, i]]
  loss_dcae = [float(x) for x in loss_dcae[:, i]]
  length_dcae = [float(x) for x in length_dcae[:, i]]
  # Feel free to make the plot prettier.
  plt.figure(figsize=(10,5))
  plt.scatter(length_cae, loss_cae, label='CAE')
  plt.scatter(length_dcae, loss_dcae, label='denoising CAE')
  plt.xlabel('Noise length')
  plt.ylabel('Loss')
  plt.legend()

# %% [markdown]
# ### Visualizing interpolation

# %% [markdown]
# Congrats on getting this far! Here is a final question.
#
# **Question 8: interpolating latents**
#
# Estimated time: 30 min to 1 hour.
#
# Suppose the encoder is E, decoder is D. We essentially did the following: yhat = D(E(y)) where y is the input and yhat is the reconstructed image.
#
# Let z = E(y), so z is called the latent. Specifically, we obtain z after the batch normalization / pooling layers of the encoder.
#
# Now, let's try interpolating the z for one image and the z for another image!
#
# TODO:
# - Suppose the 0th image in the test set is called y0, and the 1st image in the test set is called y1. They correspond to latents z0 and z1 respectively.
# - Now, set new z by one of the following eleven choices and then print out the reconstructed image.
#   - z = 0.0 * z0 + 1.0 * z1
#   - z = 0.1 * z0 + 0.9 * z1
#   - z = 0.2 * z0 + 0.8 * z1
#   - ...
#   - z = 1.0 * z0 + 0.0 * z1
# - So, your result (to be submitted) should be...
#   - an image generated by the following latent: z = 0.0 * z0 + 1.0 * z1
#   - an image generated by the following latent: z = 0.1 * z0 + 0.9 * z1
#   - ...
#   - an image generated by the following latent: z = 1.0 * z0 + 0.0 * z1
# - Hint: you should see that your images gradually change from y1 to y0. If y1 is a tshirt and y0 is a shoe, then you should see that the images change gradually from a tshirt to a shoe.
# - You only need to do this for the regular CAE.
# - Explain clearly what your y1 is, and what your y0 is.
#
#
#
#
#
# Here is some code which may be helpful. You don't need to use the below.
# ```
#     model_children = list(model.children())
#     print("model children: ", model_children)
# ```
# You can use elements in model_children to process your inputs. You can also add another helper function (other than init and forward) in the CAE class. Your call!

# %%
autoencoder = CAE()
autoencoder.load_state_dict(torch.load('/content/drive/My Drive/DS1008/HW3/model.pth')["model"])
autoencoder.cpu()
# Out:
# CAE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (8): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   )
# )

# %%
model_children = list(autoencoder.children())
print("model children: ", model_children)
# Out:
# model children:  [Sequential(
#   (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU()
#   (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
# ), Sequential(
#   (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU()
#   (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   (8): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
# )]

# %%
y_0, y_1 = next(iter(test_loader))[0][0:1], next(iter(test_loader))[0][1:2]

# %%
def imshow(img):
    # First unnormalize if we want to print out the image. We're using the
    # convention that each image pixel is between -1 and 1. But when python
    # prints out images, the pixel needs to be between 0 and 1.
    img = img / 2 + 0.5
    img_numpy = img.numpy()
    plt.figure(figsize=(3, 3))
    plt.imshow(np.transpose(img_numpy, (1, 2, 0)))

# %%
y_0.shape
# Out:
# torch.Size([1, 1, 28, 28])

# %% [markdown]
# $y_0$: shoe

# %%
imshow(torchvision.utils.make_grid(y_0.data))

# %% [markdown]
# $y_1$: t-shirt

# %%
imshow(torchvision.utils.make_grid(y_1.data))

# %%
def visualize_one_model(model, image_id, image_id2, gamma1):
    model.eval()
    encoder, decoder = list(autoencoder.children())
    z_0 = encoder(image_id.view(1,-1,28,28))
    z_1 = encoder(image_id2.view(1,-1,28,28))
    z = gamma1*z_0 + (1-gamma1)*z_1
    image = decoder(z).view(28,28).detach()
    imshow(torchvision.utils.make_grid(image.data))

# %%
for k in np.arange(0, 1.01, 0.1):
  print('k =', k)
  visualize_one_model(autoencoder, y_0, y_1, k)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# k = 0.0
# k = 0.1
# k = 0.2
# k = 0.30000000000000004
# k = 0.4
# k = 0.5
# k = 0.6000000000000001
# k = 0.7000000000000001
# k = 0.8
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# k = 0.9
# k = 1.0
